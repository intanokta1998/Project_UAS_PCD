# %%
import cv2

img = cv2.imread('jimin.jpg')
img_resize = cv2.resize(img, (600, 350))  
edged = cv2.Canny(img_resize, 240, 260)
cv2.imshow("Original Image",img_resize)
cv2.imshow("Edged Image", edged)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
test_image = cv2.imread('jimin.jpg',0) 
sobelx = cv2.Sobel(test_image,cv2.CV_64F,1,0,ksize=3)
sobely = cv2.Sobel(test_image,cv2.CV_64F,0,1,ksize=3)
plt.figure()
plt.subplot(1,2,1),plt.imshow(sobelx,cmap='gray'),plt.title('Penerapan Sobel X')
plt.subplot(1,2,2),plt.imshow(sobely,cmap='gray'),plt.title('Penerapan Sobel Y')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1d3e33ad608>,
#  <matplotlib.image.AxesImage at 0x1d3e3bbe348>,
#  Text(0.5, 1.0, 'Penerapan Sobel Y'))

# %%
import cv2
im = cv2.imread('jimin.jpg')
print(im)
# Out:
# [[[212 134 135]
#   [212 134 135]
#   [212 134 135]
#   ...
#   [237 235 234]
#   [228 226 225]
#   [218 216 215]]
#
#  [[212 134 135]
#   [212 134 135]
#   [212 134 135]
#   ...
#   [238 236 235]
#   [229 227 226]
#   [219 217 216]]
#
#  [[212 134 135]
#   [212 134 135]
#   [212 134 135]
#   ...
#   [238 236 235]
#   [230 228 227]
#   [221 219 218]]
#
#  ...
#
#  [[224 197 177]
#   [221 197 179]
#   [215 197 180]
#   ...
#   [231 209 197]
#   [233 216 203]
#   [233 215 204]]
#
#  [[228 195 175]
#   [225 196 175]
#   [218 197 176]
#   ...
#   [231 209 197]
#   [233 216 203]
#   [233 215 204]]
#
#  [[229 195 172]
#   [226 195 172]
#   [220 195 175]
#   ...
#   [231 209 197]
#   [233 216 203]
#   [233 215 204]]]
